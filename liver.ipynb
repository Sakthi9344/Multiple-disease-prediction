# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'D:\guvi\Projects\.venv\project_4_multiple_disease_prediction\indian_liver_patient - indian_liver_patient.csv')

# %%
import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_columns = 500

df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [583 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Albumin_and_Globulin_Ratio    4
# Gender                        0
# Age                           0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alamine_Aminotransferase      0
# Alkaline_Phosphotase          0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Dataset                       0
# dtype: int64

# %%
df["Albumin_and_Globulin_Ratio"].fillna(df["Albumin_and_Globulin_Ratio"].mode().iloc[0], inplace=True)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# std                  182.620356                  288.918529        1.085451
# min                   10.000000                   10.000000        2.700000
# 25%                   23.000000                   25.000000        5.800000
# 50%                   35.000000                   42.000000        6.600000
# 75%                   60.500000                   87.000000        7.200000
# max                 2000.000000                 4929.000000        9.600000
#
#           Albumin  Albumin_and_Globulin_Ratio     Dataset
# count  583.000000                  583.000000  583.000000
# mean     3.141852                    0.947427    1.286449
# std      0.795519                    0.318522    0.452490
# min      0.900000                    0.300000    1.000000
# 25%      2.600000                    0.700000    1.000000
# 50%      3.100000                    0.950000    1.000000
# 75%      3.800000                    1.100000    2.000000
# max      5.500000                    2.800000    2.000000

# %%
df["Gender"] = df["Gender"].map({"Female":0 , "Male":1})

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
correlation_matrix = df.corr()

target_col = "Dataset"

threshold = 0.1

high_corr_features = correlation_matrix[target_col][correlation_matrix[target_col].abs()>threshold].index.tolist()

high_corr_features.remove(target_col)   

high_corr_features
# Out:
# ['Age',
#  'Total_Bilirubin',
#  'Direct_Bilirubin',
#  'Alkaline_Phosphotase',
#  'Alamine_Aminotransferase',
#  'Aspartate_Aminotransferase',
#  'Albumin',
#  'Albumin_and_Globulin_Ratio']

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

scaler = {}

for col in high_corr_features:
    ssc = StandardScaler()
    df[col] = ssc.fit_transform(df[[col]])
    scaler[col] = ssc

scaler
# Out:
# {'Age': StandardScaler(),
#  'Total_Bilirubin': StandardScaler(),
#  'Direct_Bilirubin': StandardScaler(),
#  'Alkaline_Phosphotase': StandardScaler(),
#  'Alamine_Aminotransferase': StandardScaler(),
#  'Aspartate_Aminotransferase': StandardScaler(),
#  'Albumin': StandardScaler(),
#  'Albumin_and_Globulin_Ratio': StandardScaler()}

# %%
x,y = df[high_corr_features],df["Dataset"]

y.value_counts()
# Out:
# Dataset
# 1    416
# 2    167
# Name: count, dtype: int64

# %%
# Balancing of Data

from imblearn.over_sampling import RandomOverSampler

over_sampling = RandomOverSampler()

x_resample , y_resample = over_sampling.fit_resample(x,y)

# from imblearn.under_sampling import RandomUnderSampler

# under_sampling = RandomUnderSampler()

# x_resample , y_resample = under_sampling.fit_resample(x,y)

# %%
y_resample.value_counts()
# Out:
# Dataset
# 1    416
# 2    416
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(x_resample,y_resample,random_state=42)

# %%
from sklearn.metrics import accuracy_score,classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

models = {"LogisticRegression" : LogisticRegression(),
          "DecisionTreeClassifier" : DecisionTreeClassifier(),
          "RandomForestClassifier" : RandomForestClassifier(),
          "GradientBoostingClassifier" : GradientBoostingClassifier(),
          "SVC" : SVC(),
          "KNeighborsClassifier" : KNeighborsClassifier()}

results = {}

for name, model in models.items():
    model.fit(X_train,Y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(Y_test,y_pred)
    results[name] = acc
    print(f"\n{name} Accuracy: {acc:.4f}")
    print(classification_report(Y_test, y_pred))

best_model = max(results, key=results.get)
print("\n Best Model is:", best_model, "with Accuracy:", results[best_model])
# Out:
# LogisticRegression Accuracy: 0.7067
#               precision    recall  f1-score   support
#
#            1       0.77      0.54      0.63        98
#            2       0.68      0.85      0.76       110
#
#     accuracy                           0.71       208
#    macro avg       0.72      0.70      0.69       208
# weighted avg       0.72      0.71      0.70       208
#
#
# DecisionTreeClassifier Accuracy: 0.8510
#               precision    recall  f1-score   support
#
#            1       0.92      0.74      0.82        98
#            2       0.81      0.95      0.87       110
#
#     accuracy                           0.85       208
#    macro avg       0.87      0.85      0.85       208
# weighted avg       0.86      0.85      0.85       208
#
#
# RandomForestClassifier Accuracy: 0.8606
#               precision    recall  f1-score   support
#
#            1       0.91      0.79      0.84        98
#            2       0.83      0.93      0.88       110
#
#     accuracy                           0.86       208
#    macro avg       0.87      0.86      0.86       208
# weighted avg       0.87      0.86      0.86       208
#
#
# GradientBoostingClassifier Accuracy: 0.8462
#               precision    recall  f1-score   support
#
#            1       0.91      0.74      0.82        98
#            2       0.80      0.94      0.87       110
#
#     accuracy                           0.85       208
#    macro avg       0.86      0.84      0.84       208
# weighted avg       0.86      0.85      0.84       208
#
#
# SVC Accuracy: 0.6923
#               precision    recall  f1-score   support
#
#            1       0.78      0.48      0.59        98
#            2       0.66      0.88      0.75       110
#
#     accuracy                           0.69       208
#    macro avg       0.72      0.68      0.67       208
# weighted avg       0.72      0.69      0.68       208
#
#
# KNeighborsClassifier Accuracy: 0.7163
#               precision    recall  f1-score   support
#
#            1       0.73      0.62      0.67        98
#            2       0.70      0.80      0.75       110
#
#     accuracy                           0.72       208
#    macro avg       0.72      0.71      0.71       208
# weighted avg       0.72      0.72      0.71       208
#
#
#  Best Model is: RandomForestClassifier with Accuracy: 0.8605769230769231

# %%
final_model = models[best_model]

final_model
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test,final_model.predict(X_test))

cm
# Out:
# array([[ 77,  21],
#        [  8, 102]])

# %%
import pickle
pickle_out = open("l_final_model.pkl","wb")
pickle.dump(final_model,pickle_out)
pickle_out.close()

# %%
pickle_out = open("l_scaler.pkl","wb")
pickle.dump(scaler,pickle_out)
pickle_out.close()
